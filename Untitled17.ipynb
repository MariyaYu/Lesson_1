# %% [markdown]
# <a href="https://colab.research.google.com/github/MariyaYu/Lesson_1/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats
from scipy.stats import shapiro
from scipy.stats import anderson
from scipy.stats import kstest
from scipy.stats import mannwhitneyu
data = pd.read_excel('Nasdaq.xlsx')
df = pd.DataFrame(data)
df
# Out:
#       Unnamed: 0 Symbol                                               Name  \
# 0            871    BAM      Brookfield Asset Management Inc. Common Stock
# 1           2048    CVR           Chicago Rivet & Machine Co. Common Stock
# 2           4491    LGL                  LGL Group Inc. (The) Common Stock
# 3           1526    CET        Central Securities Corporation Common Stock
# 4           5166    NBR                             Nabors Industries Ltd.
# ...          ...    ...                                                ...
# 3900        8254   XPDB  Power & Digital Infrastructure Acquisition II ...
# 3901        8256  XPDBW  Power & Digital Infrastructure Acquisition II ...
# 3902        8264   XPON                        Expion360 Inc. Common Stock
# 3903        8322   ZING   FTAC Zeus Acquisition Corp. Class A Common Stock
# 3904        8324  ZINGW                FTAC Zeus Acquisition Corp. Warrant
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3905 entries, 0 to 3904
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3905 non-null   int64
#  1   Symbol      3905 non-null   object
#  2   Name        3905 non-null   object
#  3   Last Sale   3905 non-null   object
#  4   Net Change  3905 non-null   float64
#  5   % Change    3905 non-null   object
#  6   Market Cap  3905 non-null   int64
#  7   Country     3905 non-null   object
#  8   IPO Year    3905 non-null   int64
#  9   Volume      3905 non-null   int64
#  10  Sector      3905 non-null   object
#  11  Industry    3905 non-null   object
#  12  Z           3905 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 396.7+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0   Net Change    Market Cap     IPO Year        Volume
# count  3905.000000  3905.000000  3.905000e+03  3905.000000  3.905000e+03
# mean   4170.461460    -0.991582  5.754744e+09  2013.071703  5.780370e+05
# std    2377.129162     4.169152  6.353889e+10    10.522540  2.639760e+06
# min       0.000000  -170.985000  0.000000e+00  1925.000000  1.000000e+00
# 25%    2191.000000    -0.730000  3.427910e+07  2007.000000  9.897000e+03
# 50%    4181.000000    -0.170000  2.704117e+08  2018.000000  7.495700e+04
# 75%    6236.000000    -0.010000  1.165274e+09  2021.000000  3.249490e+05
# max    8356.000000     7.380000  2.330135e+12  2022.000000  6.188427e+07

# %%
df.isnull()
# Out:
#       Unnamed: 0  Symbol   Name  Last Sale  Net Change  % Change  Market Cap  \
# 0          False   False  False      False       False     False       False
# 1          False   False  False      False       False     False       False
# 2          False   False  False      False       False     False       False
# 3          False   False  False      False       False     False       False
# 4          False   False  False      False       False     False       False
# ...          ...     ...    ...        ...         ...       ...         ...
# 3900       False   False  False      False       False     False       False
# 3901       False   False  False      False       False     False       False
# 3902       False   False  False      False       False     False       False
# 3903       False   False  False      False       False     False       False
# 3904       False   False  False      False       False     False       False
#
# ...

# %%
# пустые ячейки отсутствуют
# видим, что много столбцов не имеют формат даты и времени, не рассматриваютмя Pandas (обозначены как object). Также видим, что столбцы не содержат пропуски.
